# %% [markdown]
# # 1. EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
game = pd.read_csv('vgames2.csv', index_col = 0)
sales_col = ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']
game.head()
# Out:
#                                              Name Platform    Year      Genre  \
# 1                    Candace Kane's Candy Factory       DS  2008.0     Action
# 2                                  The Munchables      Wii  2009.0     Action
# 3  Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010.0  Adventure
# 4                Deal or No Deal: Special Edition       DS  2010.0       Misc
# 5       Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010.0   Platform
#
#             Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 1           Destineer     0.04        0        0           0
# 2  Namco Bandai Games     0.17        0        0        0.01
# 3           Alchemist        0        0     0.02           0
# 4           Zoo Games     0.04        0        0           0
# 5         D3Publisher     0.12     0.09        0        0.04

# %%
# Year, Genre, Publisher null rows
game.info()
game.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16598 entries, 1 to 16598
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         16598 non-null  object
#  1   Platform     16598 non-null  object
#  2   Year         16327 non-null  float64
#  3   Genre        16548 non-null  object
#  4   Publisher    16540 non-null  object
#  5   NA_Sales     16598 non-null  object
#  6   EU_Sales     16598 non-null  object
#  7   JP_Sales     16598 non-null  object
#  8   Other_Sales  16598 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 1.3+ MB
# Name             0
# Platform         0
# Year           271
# Genre           50
# Publisher       58
# NA_Sales         0
# EU_Sales         0
# JP_Sales         0
# Other_Sales      0
# dtype: int64

# %%
# Since enough data exist will remove all data with null values
# It is hard to assume which genre it will go in for
# For Example the Game Series Need for speed is in Action or Racing Depending on its series.

# %%
game_clean = game.copy()

# %% [markdown]
# ## 1 - 1 Remove Missing Values

# %%
game_clean = game_clean.dropna(subset = ['Year' ,'Genre', 'Publisher'])
game_clean = game_clean[game_clean['Publisher'] != 'Unknown']
game_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16142 entries, 1 to 16598
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         16142 non-null  object
#  1   Platform     16142 non-null  object
#  2   Year         16142 non-null  float64
#  3   Genre        16142 non-null  object
#  4   Publisher    16142 non-null  object
#  5   NA_Sales     16142 non-null  object
#  6   EU_Sales     16142 non-null  object
#  7   JP_Sales     16142 non-null  object
#  8   Other_Sales  16142 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 1.2+ MB

# %% [markdown]
# ## 1 - 2 Sales Column

# %%
# game_clean = game_clean.astype({'NA_Sales' : 'float64', 'EU_Sales' : 'float64' ,'JP_Sales' : 'float64', 'Other_Sales' : 'float64'})
# game_clean.info()
# M/K exits in our data set.
# sales column에 있는 정보들은 출고량이라고 한다.
# 과연 0으로 표기 되있는 출고량들은 k 혹은 m의 단위로 소수점을 지우다가 0이 된것일까
# 아니면 진짜로 특정 지역에서 출고를 하지 않은 것일까

# %%
def check_num_sales(df, col):
    num_k = df[col].str.contains('K').sum()
    num_m = df[col].str.contains('M').sum()
    num_0 = len(df[df[col] == '0'])
    non_k_m_0 = df[(~df[col].str.contains('K')) & 
                       (~df[col].str.contains('M')) & 
                       (~(df[col] == '0'))]
    num_float = non_k_m_0[col].str.contains('.').sum()
    num_non_k_m_0 = len(non_k_m_0)
    
    total = num_k + num_m + num_0 + num_non_k_m_0
    
    print('num K : ', num_k)
    print('num M : ', num_m)
    print('num 0 : ', num_0)
    print('num non K M 0 : ', num_non_k_m_0)
    print('num not k m 0 float : ', num_float)
    print('Sum : ', total, ' Expected : ', len(df))

# %%
for col in sales_col:
    print(col)
    check_num_sales(game_clean, col)
    print()
# Out:
# NA_Sales
# num K :  94
# num M :  97
# num 0 :  4311
# num non K M 0 :  11640
# num not k m 0 float :  11640
# Sum :  16142  Expected :  16142
#
# EU_Sales
# num K :  97
# num M :  97
# num 0 :  5498
# num non K M 0 :  10450
# num not k m 0 float :  10450
# Sum :  16142  Expected :  16142
#
# JP_Sales
# num K :  98
# num M :  98
# num 0 :  9985
# num non K M 0 :  5961
# num not k m 0 float :  5961
# Sum :  16142  Expected :  16142
#
# Other_Sales
# num K :  95
# num M :  99
# num 0 :  6162
# num non K M 0 :  9786
# num not k m 0 float :  9786
# Sum :  16142  Expected :  16142

# %%
# Any row with K is in unit of 10 and greater than 10 except 0 as sales

game_clean[game_clean['NA_Sales'].str.contains('K')]
game_clean[game_clean['EU_Sales'].str.contains('K')]
game_clean[game_clean['JP_Sales'].str.contains('K')]
game_clean[game_clean['Other_Sales'].str.contains('K')]

# Any row with M has a value smaller than 10
game_clean[game_clean['NA_Sales'].str.contains('M')]
game_clean[game_clean['EU_Sales'].str.contains('M')]
game_clean[game_clean['JP_Sales'].str.contains('M')]
game_clean[game_clean['Other_Sales'].str.contains('M')]


print(game_clean['NA_Sales'].str.contains('M').sum())
print(game_clean['EU_Sales'].str.contains('M').sum())
print(game_clean['JP_Sales'].str.contains('M').sum())
print(game_clean['Other_Sales'].str.contains('M').sum())
# Out:
# 97
# 97
# 98
# 99

# %%
# 1. K가 붙어야되는것들 찾기
# 2. K 붙여주고 갯수 확인하기
# 3. K 000으로 바꿔주기


# k를 가지고 있는 index 저장해두기
# k대신 000 만들어주고
# m 지워주고 
# k 대신 000 써줬던 index 다시 1000으로 나눠주기

# %%
def replace_k(df, col):
    k_index = df[col].str.contains('K')
    df[col] = df[col].str.replace('K', '000')
    df[col] = df[col].str.replace('M', '')
    df[col] = df[col].astype('float64')
    df.loc[k_index, col] = df.loc[k_index, col] / 1000000

# %%
for col in sales_col:
    replace_k(game_clean, col)

# %%
game_clean['Total_Sales'] = game_clean['NA_Sales'] + game_clean['EU_Sales'] + game_clean['JP_Sales'] + game_clean['Other_Sales']
game_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16142 entries, 1 to 16598
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         16142 non-null  object
#  1   Platform     16142 non-null  object
#  2   Year         16142 non-null  float64
#  3   Genre        16142 non-null  object
#  4   Publisher    16142 non-null  object
#  5   NA_Sales     16142 non-null  float64
#  6   EU_Sales     16142 non-null  float64
#  7   JP_Sales     16142 non-null  float64
#  8   Other_Sales  16142 non-null  float64
#  9   Total_Sales  16142 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# ## 1 - 2 Year Column float -> int

# %%
game_clean['Year'] = game_clean['Year'].astype('int')
game_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16142 entries, 1 to 16598
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         16142 non-null  object
#  1   Platform     16142 non-null  object
#  2   Year         16142 non-null  int64
#  3   Genre        16142 non-null  object
#  4   Publisher    16142 non-null  object
#  5   NA_Sales     16142 non-null  float64
#  6   EU_Sales     16142 non-null  float64
#  7   JP_Sales     16142 non-null  float64
#  8   Other_Sales  16142 non-null  float64
#  9   Total_Sales  16142 non-null  float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
game_clean[(game_clean['Year'] < 100) & (game_clean['Year'] >= 22)]
# Out:
#                                             Name Platform  Year      Genre  \
# 82                         Treasures of the Deep       PS    97     Action
# 907    Mini-Yonku Shining Scorpion: Let's & Go!!     SNES    96     Racing
# 2430                                      Casper       PS    96  Adventure
# 3493                                      Glover      N64    98   Platform
# 4366                            Adventure Island      NES    86   Platform
# 4808                                  Virtua Cop      SAT    95    Shooter
# 4840                          Mobile Suit Gundam       PS    95     Action
# 10316                       AeroFighters Assault      N64    97     Action
# 10706                                3D Baseball       PS    96     Sports
# 11335                  Super Fire ProWrestling X     SNES    95   Fighting
# 14573                                  S.C.A.R.S       PS    98     Racing
# 14786                     GOTHA: Ismailia Seneki      SAT    95   Strategy
# 15986                             Sugoi Hebereke     SNES    94   Fighting
# 16483           Super Robot Taisen F Kanketsuhen      SAT    98   Strategy
#
#                            Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 82                Namco Bandai Games      0.10      0.07      0.00
# 907              ASCII Entertainment      0.00      0.00      0.90
# 2430                       Interplay      0.46      0.31      0.00
# 3493              Hasbro Interactive      0.72      0.17      0.00
# 4366                     Hudson Soft      0.00      0.00      1.05
# 4808                            Sega      0.00      0.00      0.62
# 4840              Namco Bandai Games      0.00      0.00      0.42
# 10316                   Video System      0.15      0.04      0.00
# 10706  BMG Interactive Entertainment      0.02      0.01      0.00
# 11335            Human Entertainment      0.00      0.00      0.28
# 14573                        Ubisoft      0.05      0.03      0.00
# 14786                           Sega      0.00      0.00      0.08
# 15986                        Sunsoft      0.00      0.00      0.02
# 16483                      Banpresto      0.00      0.00      0.55
#
#        Other_Sales  Total_Sales
# 82            0.01         0.18
# 907           0.00         0.90
# 2430          0.05         0.82
# 3493          0.01         0.90
# 4366          0.00         1.05
# 4808          0.00         0.62
# 4840          0.03         0.45
# 10316         0.00         0.19
# 10706         0.00         0.03
# 11335         0.00         0.28
# 14573         0.01         0.09
# 14786         0.00         0.08
# 15986         0.00         0.02
# 16483         0.00         0.55

# %%
game_clean.loc[(game_clean['Year'] < 100) & (game_clean['Year'] >= 22), 'Year'] += 1900

# %%
game_clean[(game_clean['Year'] < 21) & (game_clean['Year'] >= 0)]
# Out:
#                                                Name Platform  Year     Genre  \
# 75          Age of Empires III: Complete Collection       PC     9  Strategy
# 214                                NASCAR Unleashed      PS3    11    Racing
# 305    Kung Fu Panda: Showdown of Legendary Legends      PS3    15    Action
# 769                             NASCAR Thunder 2004      PS2     3    Racing
# 1016                                    Wolfenstein       PC     9   Shooter
# ...                                             ...      ...   ...       ...
# 15613               Rally Fusion: Race of Champions      PS2     2    Racing
# 15837                      Theatrhythm Dragon Quest      3DS    15      Misc
# 16104                                  Fab 5 Soccer       DS     8    Sports
# 16150                    Dragon Ball Z: Burst Limit     X360     8  Fighting
# 16395                                 Point Blank 3       PS     0   Shooter
#
#                     Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 75     Microsoft Game Studios      0.01      0.12      0.00         0.03
# 214                Activision      0.09      0.00      0.00         0.01
# 305              Little Orbit      0.00      0.02      0.00         0.00
# 769           Electronic Arts      0.53      0.41      0.00         0.14
# 1016               Activision      0.01      0.03      0.00         0.01
# ...                       ...       ...       ...       ...          ...
# 15613              Activision      0.06      0.05      0.00         0.02
# 15837             Square Enix      0.00      0.00      0.15         0.00
# 16104               Destineer      0.01      0.00      0.00         0.00
# 16150                   Atari      0.24      0.18      0.03         0.05
# 16395      Namco Bandai Games      0.01      0.01      0.00         0.00
#
#        Total_Sales
# 75            0.16
# 214           0.10
# 305           0.02
# 769           1.08
# 1016          0.05
# ...            ...
# 15613         0.13
# 15837         0.15
# 16104         0.01
# 16150         0.50
# 16395         0.02
#
# [86 rows x 10 columns]

# %%
game_clean.loc[(game_clean['Year'] < 22) & (game_clean['Year'] >= 0), 'Year'] += 2000

# %% [markdown]
# ## Explore

# %%
game_clean.describe()
# Out:
#                Year      NA_Sales      EU_Sales      JP_Sales   Other_Sales  \
# count  16142.000000  16142.000000  16142.000000  16142.000000  16142.000000
# mean    2006.384897      0.266477      0.148053      0.078557      0.048469
# std        5.832554      0.824725      0.509739      0.310063      0.190214
# min     1980.000000      0.000000      0.000000      0.000000      0.000000
# 25%     2003.000000      0.000000      0.000000      0.000000      0.000000
# 50%     2007.000000      0.080000      0.020000      0.000000      0.010000
# 75%     2010.000000      0.240000      0.110000      0.040000      0.040000
# max     2020.000000     41.490000     29.020000     10.220000     10.570000
#
#         Total_Sales
# count  16142.000000
# mean       0.541556
# std        1.568240
# min        0.000000
# 25%        0.060000
# 50%        0.170000
# 75%        0.480000
# max       82.740000

# %%
game_clean.nunique()
# Out:
# Name           11218
# Platform          31
# Year              39
# Genre             12
# Publisher        574
# NA_Sales         407
# EU_Sales         303
# JP_Sales         241
# Other_Sales      156
# Total_Sales     1004
# dtype: int64

# %%
game_clean[game_clean.duplicated(['Name'], keep = False)].sort_values('Name')
# Out:
#                                Name Platform  Year   Genre  \
# 2661         007: Quantum of Solace      PS2  2008  Action
# 5505         007: Quantum of Solace      Wii  2008  Action
# 16281        007: Quantum of Solace     X360  2008  Action
# 8868         007: Quantum of Solace       PC  2008  Action
# 6840         007: Quantum of Solace      PS3  2008  Action
# ...                             ...      ...   ...     ...
# 13758     pro evolution soccer 2011      Wii  2010  Sports
# 5797      pro evolution soccer 2011      PS3  2010  Sports
# 2710      pro evolution soccer 2011     X360  2010  Sports
# 15022  uDraw Studio: Instant Artist      Wii  2011    Misc
# 3063   uDraw Studio: Instant Artist     X360  2011    Misc
#
#                           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 2661                     Activision      0.17      0.00      0.00
# 5505                     Activision      0.30      0.29      0.01
# 16281                    Activision      0.82      0.52      0.01
# 8868                     Activision      0.01      0.01      0.00
# 6840                     Activision      0.43      0.52      0.02
# ...                             ...       ...       ...       ...
# 13758  Konami Digital Entertainment      0.08      0.10      0.03
# 5797   Konami Digital Entertainment      0.29      1.18      0.54
# 2710   Konami Digital Entertainment      0.09      0.44      0.00
# 15022                           THQ      0.08      0.09      0.00
# 3063                            THQ      0.01      0.01      0.00
#
#        Other_Sales  Total_Sales
# 2661          0.26         0.43
# 5505          0.07         0.67
# 16281         0.14         1.49
# 8868          0.00         0.02
# 6840          0.20         1.17
# ...            ...          ...
# 13758         0.02         0.23
# 5797          0.41         2.42
# 2710          0.07         0.60
# 15022         0.02         0.19
# 3063          0.00         0.02
#
# [7620 rows x 10 columns]

# %%
game_clean.to_csv('vgames2_clean.csv')

# %% [markdown]
# ## Outliers

# %%
# Sales Outlier
na = game_clean['NA_Sales'] == 0
eu = game_clean['EU_Sales'] == 0
jp = game_clean['JP_Sales'] == 0
other = game_clean['Other_Sales'] == 0
total = game_clean['Total_Sales'] == 0
at_least_one = game_clean[na | eu | jp | other]

print('NA Sales 0 : ', na.sum())
print('EU Sales 0 : ', eu.sum())
print('JP Sales 0 : ', jp.sum())
print('Other Sales 0 : ', other.sum())
print('At least one Sales 0 : ', len(at_least_one))
print('Total Sales 0 : ', total.sum())
# Out:
# NA Sales 0 :  4365
# EU Sales 0 :  5562
# JP Sales 0 :  10104
# Other Sales 0 :  6249
# At least one Sales 0 :  13789
# Total Sales 0 :  1

# %%
fig, ax = plt.subplots()
ax.boxplot(game_clean[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Total_Sales']])
plt.show()

# %%
game_clean.describe()
# Out:
#                Year      NA_Sales      EU_Sales      JP_Sales   Other_Sales  \
# count  16142.000000  16142.000000  16142.000000  16142.000000  16142.000000
# mean    2006.384897      0.266477      0.148053      0.078557      0.048469
# std        5.832554      0.824725      0.509739      0.310063      0.190214
# min     1980.000000      0.000000      0.000000      0.000000      0.000000
# 25%     2003.000000      0.000000      0.000000      0.000000      0.000000
# 50%     2007.000000      0.080000      0.020000      0.000000      0.010000
# 75%     2010.000000      0.240000      0.110000      0.040000      0.040000
# max     2020.000000     41.490000     29.020000     10.220000     10.570000
#
#         Total_Sales
# count  16142.000000
# mean       0.541556
# std        1.568240
# min        0.000000
# 25%        0.060000
# 50%        0.170000
# 75%        0.480000
# max       82.740000

# %%
q1 = game_clean['Total_Sales'].describe()['25%']
q3 = game_clean['Total_Sales'].describe()['75%']
iqr = q3 - q1
upper = q3 + 1.5 * iqr
lower = q1 - 1.5 * iqr
game_total_outlier = game_clean[(game_clean['Total_Sales'] <= upper) & (game_clean['Total_Sales'] >= lower)]
game_total_outlier = game_total_outlier[game_total_outlier['Total_Sales'] <= 0.7]
len(game_total_outlier)
# Out:
# 13288

# %%
fig, ax = plt.subplots()
ax.boxplot(game_total_outlier[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Total_Sales']])
plt.show()

# %%
game_total_outlier.describe()
# Out:
#                Year      NA_Sales      EU_Sales      JP_Sales   Other_Sales  \
# count  13288.000000  13288.000000  13288.000000  13288.000000  13288.000000
# mean    2006.675722      0.091529      0.042245      0.035862      0.014399
# std        5.493729      0.113454      0.067555      0.086071      0.025869
# min     1980.000000      0.000000      0.000000      0.000000      0.000000
# 25%     2003.000000      0.000000      0.000000      0.000000      0.000000
# 50%     2007.000000      0.050000      0.010000      0.000000      0.010000
# 75%     2010.000000      0.140000      0.050000      0.030000      0.020000
# max     2020.000000      0.640000      0.660000      0.700000      0.600000
#
#         Total_Sales
# count  13288.000000
# mean       0.184034
# std        0.171284
# min        0.000000
# 25%        0.050000
# 50%        0.120000
# 75%        0.270000
# max        0.700000

# %%
q1 = game_clean['NA_Sales'].describe()['25%']
q3 = game_clean['NA_Sales'].describe()['75%']
iqr = q3 - q1
upper = q3 + 1.5 * iqr
lower = q1 - 1.5 * iqr
game_indv = game_clean[(game_clean['NA_Sales'] <= upper) & (game_clean['NA_Sales'] >= lower)]
# game_total_outlier = game_total_outlier[game_total_outlier['Total_Sales'] <= 0.7]
len(game_indv)
# Out:
# 14494

# %%
q1 = game_clean['EU_Sales'].describe()['25%']
q3 = game_clean['EU_Sales'].describe()['75%']
iqr = q3 - q1
upper = q3 + 1.5 * iqr
lower = q1 - 1.5 * iqr
game_indv = game_indv[(game_indv['EU_Sales'] <= upper) & (game_indv['EU_Sales'] >= lower)]
# game_total_outlier = game_total_outlier[game_total_outlier['Total_Sales'] <= 0.7]
len(game_indv)
# Out:
# 13578

# %%
q1 = game_clean['JP_Sales'].describe()['25%']
q3 = game_clean['JP_Sales'].describe()['75%']
iqr = q3 - q1
upper = q3 + 1.5 * iqr
lower = q1 - 1.5 * iqr
game_indv = game_indv[(game_indv['JP_Sales'] <= upper) & (game_indv['JP_Sales'] >= lower)]
# game_total_outlier = game_total_outlier[game_total_outlier['Total_Sales'] <= 0.7]
len(game_indv)
# Out:
# 11768

# %%
q1 = game_clean['Other_Sales'].describe()['25%']
q3 = game_clean['Other_Sales'].describe()['75%']
iqr = q3 - q1
upper = q3 + 1.5 * iqr
lower = q1 - 1.5 * iqr
game_indv = game_indv[(game_indv['Other_Sales'] <= upper) & (game_indv['Other_Sales'] >= lower)]
# game_total_outlier = game_total_outlier[game_total_outlier['Total_Sales'] <= 0.7]
len(game_indv)
# Out:
# 11643

# %%
fig, ax = plt.subplots()
ax.boxplot(game_indv[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Total_Sales']])
plt.show()

# %%
game_indv.describe()
# Out:
#                Year      NA_Sales      EU_Sales      JP_Sales   Other_Sales  \
# count  11643.000000  11643.000000  11643.000000  11643.000000  11643.000000
# mean    2006.927854      0.101351      0.041704      0.010470      0.013207
# std        5.211333      0.120866      0.059005      0.022326      0.018536
# min     1980.000000      0.000000      0.000000      0.000000      0.000000
# 25%     2004.000000      0.000000      0.000000      0.000000      0.000000
# 50%     2008.000000      0.060000      0.020000      0.000000      0.010000
# 75%     2010.000000      0.150000      0.060000      0.010000      0.020000
# max     2020.000000      0.600000      0.270000      0.100000      0.100000
#
#         Total_Sales
# count  11643.000000
# mean       0.166732
# std        0.168108
# min        0.000000
# 25%        0.040000
# 50%        0.100000
# 75%        0.240000
# max        0.940000

# %%
game_clean[game_clean['NA_Sales'] == game_clean['NA_Sales'].max()]
game_clean[game_clean['JP_Sales'] == game_clean['JP_Sales'].max()]
# Out:
#                           Name Platform  Year         Genre Publisher  \
# 7830  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Total_Sales
# 7830     11.27      8.89     10.22          1.0        31.38

# %%
game_clean[game_clean['EU_Sales'] == game_clean['EU_Sales'].max()]
# Out:
#             Name Platform  Year   Genre Publisher  NA_Sales  EU_Sales  \
# 2909  Wii Sports      Wii  2006  Sports  Nintendo     41.49     29.02
#
#       JP_Sales  Other_Sales  Total_Sales
# 2909      3.77         8.46        82.74
